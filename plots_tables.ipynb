# %%
#Full range of D, MHI_computed vs min dist to m31 or mw, whichever is closer

​

font = {'family' : 'normal',

        'weight' : 'normal',

        'size'   : 8}

​

SMALL_SIZE = 8

MEDIUM_SIZE = 10

BIGGER_SIZE = 12

​

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes

plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title

plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

​

plt.rc('font', **font)

​

sb.set_style("whitegrid")

​

​

plot_df = gals_merged[gals_merged['mw_dist'] < 2000]

plot_df.reset_index(drop=True, inplace=True)

label=[]

​

​

plot_df.rename(columns = {'Closer_MW_M31':'Closer Galaxy'}, inplace = True)

plot_df.rename(columns = {'MHI_type':'Type'}, inplace = True)

​

plot_df.replace({'detected_mass': 'Detected Mass', 'upper_limit': 'Upper Limit'},inplace=True)

​

fg = sb.FacetGrid(data=plot_df, hue='MHI_source', height = 6,aspect=1.61)

fg.set(xscale="linear", yscale="log")

​

fg = sb.scatterplot(x=plot_df['min_dist_mw_or_m31'], y=plot_df['MHI_computed'],hue=plot_df['Closer Galaxy'],style=plot_df['Type'],markers={"Detected Mass": "s", "Upper Limit": "v"},s=90,edgecolor='none',alpha=0.7)

​

for i, txt in enumerate(plot_df.GalaxyName):

    if((((plot_df['Closer Galaxy'][i] == 'M31') & (plot_df['min_dist_mw_or_m31'][i] > 300)) | ((plot_df['Closer Galaxy'][i] == 'MW') & (plot_df['min_dist_mw_or_m31'][i] > 250)) | (plot_df['Type'][i] == 'Detected Mass') | (plot_df['MHI_computed'][i] > 1000000))):

        if ('Andromeda' in txt):

            roman = txt.split('Andromeda')

            roman = ''.join(roman)

            label = "And " + roman

        elif ('LeoT' in txt):

            label = "Leo T"

        elif ('EridanusII' in txt):

            label = "Eridanus II"

        elif ('LeoA' in txt):

            label = "Leo A"

        elif ('LeoP' in txt):

            label = "Leo P"

        elif ('LeoI' in txt):

            label = "Leo I"

        elif ('AntliaB' in txt):

            label = "Antlia B"

        elif ('SagittariusdIrr' in txt):

            label = "Sag dIrr"

        elif ('SextansA' in txt):

            label = "Sextans A"

        elif ('SextansB' in txt):

            label = "Sextans B"

        elif ('PerseusI' in txt):

            label = "Perseus I"

        elif ('CetusIII' in txt):

            label = "Cetus III"

        elif ('PegasusdIrr' in txt):

            label = "Peg dIrr"

        else:

            label = txt

            

        if (txt in ['AndromedaXXVIII','SMC','Antlia','KKR25']):

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]

            label_y = plot_df['MHI_computed'].iat[i] - (plot_df['MHI_computed'].iat[i]*.29)

        elif (txt in ['LMC','LeoT','LeoI','AndromedaXVI']):

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]

            label_y = plot_df['MHI_computed'].iat[i] + (plot_df['MHI_computed'].iat[i]*.29)

        elif (txt in ['IC5152']):

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]-plot_df['min_dist_mw_or_m31'].iat[i]*.025

            label_y = plot_df['MHI_computed'].iat[i]

        elif (txt in ['ESO410-G005']):

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]-plot_df['min_dist_mw_or_m31'].iat[i]*.035

            label_y = plot_df['MHI_computed'].iat[i]

        else:

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]

            label_y = plot_df['MHI_computed'].iat[i]

        plt.annotate(label,(label_x,label_y))

​

plt.xlim(0, 2000)

plt.axvline(250,color='C0',alpha=0.7)

plt.axvline(300,color='C1',alpha=0.7)

​

plt.legend(loc='lower right')

​

plt.title("HI Mass vs Distance from Milky Way or M31")

plt.ylabel("HI Mass or Mass Limit [$M_{\odot}$]")

plt.xlabel("Distance to Milky Way or M31, whichever is closer [kpc]")

plt.show()

#Full range of D, MHI_computed vs min dist to m31 or mw, whichever is closer

​

font = {'family' : 'normal',

        'weight' : 'normal',

        'size'   : 8}

​

SMALL_SIZE = 8

MEDIUM_SIZE = 10

BIGGER_SIZE = 12

​

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes

plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title

plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

​

plt.rc('font', **font)

​

sb.set_style("whitegrid")

​

​

plot_df = gals_merged[gals_merged['mw_dist'] < 2000]

plot_df.reset_index(drop=True, inplace=True)

label=[]

​

​

plot_df.rename(columns = {'Closer_MW_M31':'Closer Galaxy'}, inplace = True)

plot_df.rename(columns = {'MHI_type':'Type'}, inplace = True)

​

plot_df.replace({'detected_mass': 'Detected Mass', 'upper_limit': 'Upper Limit'},inplace=True)

​

fg, ax = plt.subplots(figsize=(7, 5))

ax.set(xscale="linear", yscale="log")

fg = sb.scatterplot(x=plot_df[plot_df['Type'] == 'Detected Mass']['min_dist_mw_or_m31'], y=plot_df[plot_df['Type'] == 'Detected Mass']['MHI_computed'],color='C0',edgecolor='C0',marker="s",s=90,alpha=0.7)

fg = sb.scatterplot(x=plot_df[plot_df['Type'] == 'Upper Limit']['min_dist_mw_or_m31'], y=plot_df[plot_df['Type'] == 'Upper Limit']['MHI_computed'],color='none',edgecolor='C1',marker="v",s=90,alpha=0.7)

​

#fg = sb.scatterplot(x=plot_df['min_dist_mw_or_m31'], y=plot_df['MHI_computed'],hue=,style=plot_df['Type'],markers={"Detected Mass": "s", "Upper Limit": "v"},s=90,edgecolor='none',alpha=0.7)

​

for i, txt in enumerate(plot_df.GalaxyName):

    if((((plot_df['Closer Galaxy'][i] == 'M31') & (plot_df['min_dist_mw_or_m31'][i] > 300)) | ((plot_df['Closer Galaxy'][i] == 'MW') & (plot_df['min_dist_mw_or_m31'][i] > 250)) | (plot_df['Type'][i] == 'Detected Mass') | (plot_df['MHI_computed'][i] > 1000000))):

        if ('Andromeda' in txt):

            roman = txt.split('Andromeda')

            roman = ''.join(roman)

            label = "And " + roman

        elif ('LeoT' in txt):

            label = "Leo T"

        elif ('EridanusII' in txt):

            label = "Eridanus II"

        elif ('LeoA' in txt):

            label = "Leo A"

        elif ('LeoP' in txt):

            label = "Leo P"

        elif ('LeoI' in txt):

            label = "Leo I"

        elif ('AntliaB' in txt):

            label = "Antlia B"

        elif ('SagittariusdIrr' in txt):

            label = "Sag dIrr"

        elif ('SextansA' in txt):

            label = "Sextans A"

        elif ('SextansB' in txt):

            label = "Sextans B"

        elif ('PerseusI' in txt):

            label = "Perseus I"

        elif ('CetusIII' in txt):

            label = "Cetus III"

        elif ('PegasusdIrr' in txt):

            label = "Peg dIrr"

        else:

            label = txt

            

        if (txt in ['AndromedaXXVIII','SMC','Antlia','KKR25']):

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]

            label_y = plot_df['MHI_computed'].iat[i] - (plot_df['MHI_computed'].iat[i]*.29)

        elif (txt in ['LMC','LeoT','LeoI','AndromedaXVI']):

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]

            label_y = plot_df['MHI_computed'].iat[i] + (plot_df['MHI_computed'].iat[i]*.29)

        elif (txt in ['IC5152']):

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]-plot_df['min_dist_mw_or_m31'].iat[i]*.025

            label_y = plot_df['MHI_computed'].iat[i]

        elif (txt in ['ESO410-G005']):

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]-plot_df['min_dist_mw_or_m31'].iat[i]*.035

            label_y = plot_df['MHI_computed'].iat[i]

        else:

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]

            label_y = plot_df['MHI_computed'].iat[i]

        plt.annotate(label,(label_x,label_y))

​

plt.xlim(0, 2000)

plt.ylim(10, 3e9)

​

#plt.axvline(250,color='grey',alpha=0.7)

plt.axvline(300,color='grey',alpha=0.7)

​

#plt.legend(loc='lower right')

​

plt.title("HI Mass vs Distance from Milky Way or M31")

plt.ylabel("HI Mass or Mass Limit [$M_{\odot}$]")

plt.xlabel("Distance to Milky Way or M31, whichever is closer [kpc]")

plt.show()

Zoomed D, MHI_computed vs min dist to m31 or mw, whichever is closer, labels

#Zoomed in D, MHI_computed vs min dist to m31 or mw, whichever is closer

​

font = {'family' : 'normal',

        'weight' : 'normal',

        'size'   : 8}

​

SMALL_SIZE = 8

MEDIUM_SIZE = 10

BIGGER_SIZE = 12

​

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes

plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title

plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

​

plt.rc('font', **font)

​

sb.set_style("whitegrid")

​

​

plot_df = gals_merged[((gals_merged['mw_dist'] < 400) | (gals_merged['m31_dist'] < 400)) & (gals_merged['MHI_computed'] < 1000000)]

plot_df.reset_index(drop=True, inplace=True)

label=[]

​

​

plot_df.rename(columns = {'Closer_MW_M31':'Closer Galaxy'}, inplace = True)

plot_df.rename(columns = {'MHI_type':'Type'}, inplace = True)

​

plot_df.replace({'detected_mass': 'Detected Mass', 'upper_limit': 'Upper Limit'},inplace=True)

​

fg = sb.FacetGrid(data=plot_df, hue='MHI_source', height = 6,aspect=1.61)

fg.set(xscale="linear", yscale="log")

​

#fg.map(plt.scatter, 'min_dist_mw_or_m31', 'MHI_computed').add_legend()

fg = sb.scatterplot(x=plot_df['min_dist_mw_or_m31'], y=plot_df['MHI_computed'],hue=plot_df['Closer Galaxy'],style=plot_df['Type'],markers={"Detected Mass": "s", "Upper Limit": "v"},s=90,edgecolor='none',alpha=0.7)

#print(gals_merged.count())

count = 0

for i, txt in enumerate(plot_df.GalaxyName):

    if ('Andromeda' in txt):

        roman = txt.split('Andromeda')

        roman = ''.join(roman)

        label = "A" + roman

    elif ('Sag' in txt):

        tag = re.findall(r"dSph",txt) + re.findall(r"II",txt) + re.findall(r"dIrr",txt)

        tag = ''.join(tag)

        label = "Sag" + tag

    elif ('Tuc' in txt):

        tag = re.findall(r"I",txt) + re.findall(r"V",txt) + re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Tuc" + tag

    elif ('Horo' in txt):

        tag = re.findall(r"I",txt) + re.findall(r"1",txt)

        tag = ''.join(tag)

        label = "Horo" + tag

    elif ('Retic' in txt):

        tag = re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Ret" + tag

    elif ('UrsaMajor' in txt):

        tag = re.findall(r"I",txt) + re.findall(r"1",txt)

        tag = ''.join(tag)

        label = "UMa" + tag

    elif ('Bootes' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)

        tag = ''.join(tag)

        label = "Boo" + tag

    elif ('Carina' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Car" + tag

    elif ('Segue' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Seg" + tag

    elif ('Hydr' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Hyd" + tag

    elif ('Cetus' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Cet" + tag

    elif ('Triangulum' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Tri" + tag

    elif ('ComaBerenices' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Com" + tag

    elif ('UrsaMinor' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "UMi" + tag

    elif ('Pisces' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Psc" + tag

    elif ('Pictor' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Pic" + tag

    elif ('Eridan' in txt):

        tag =  re.findall(r"3",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Eri" + tag

    elif ('Hercules' in txt):

        tag =  re.findall(r"3",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Her" + tag

    elif ('CanesVenatici' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "CVn" + tag

    elif ('Columba' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Col" + tag

    elif ('Pegasus' in txt):

        tag =  re.findall(r"3",txt)+re.findall(r"dIrr",txt)

        tag = ''.join(tag)

        label = "Peg" + tag

    elif ('Draco' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Dra" + tag

    elif ('Phoenix' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Phe" + tag

    elif ('Sextans' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"A",txt)+re.findall(r"B",txt)

        tag = ''.join(tag)

        label = "Sex" + tag

    elif ('Tucana' in txt):

        tag =  re.findall(r"I",txt) + re.findall(r"V",txt)+re.findall(r"2",txt)

        tag = ''.join(tag)

        label = "Tuc" + tag

    elif ('Virgo' in txt):

        tag =  re.findall(r"I",txt)

        tag = ''.join(tag)

        label = "Vir" + tag

    elif ('Aquarius' in txt):

        tag =  re.findall(r"I",txt)

        tag = ''.join(tag)

        label = "Aqr" + tag

    elif ('Sculptor' in txt):

        tag =  re.findall(r"I",txt)

        tag = ''.join(tag)

        label = "Scl" + tag

    elif ('Crater' in txt):

        tag =  re.findall(r"I",txt)

        tag = ''.join(tag)

        label = "Crt" + tag

    elif ('Fornax' in txt):

        tag =  re.findall(r"I",txt)

        tag = ''.join(tag)

        label = "For" + tag

    elif ('Grus' in txt):

        tag =  re.findall(r"I",txt)

        tag = ''.join(tag)

        label = "Gru" + tag

    elif ('Cassiopeia' in txt):

        tag =  re.findall(r"I",txt)

        tag = ''.join(tag)

        label = "Cas" + tag

    elif ('Lacerta' in txt):

        tag =  re.findall(r"I",txt)

        tag = ''.join(tag)

        label = "Lac" + tag

    elif ('Perseus' in txt):

        tag =  re.findall(r"I",txt)

        tag = ''.join(tag)

        label = "Per" + tag

    else:

        label = txt

    

    if (txt in ['AndromedaXXVIII','SMC','Antlia','KKR25','CassiopeiaIII','AndromedaXX','AndromedaXI','LeoIV','Hercules','DESJ0225+0304','Tucana','Draco','Bootes(I)','HorologiumII','AndromedaXV','BootesIII','UrsaMinor']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]

        label_y = plot_df['MHI_computed'].iat[i] - (plot_df['MHI_computed'].iat[i]*.15)

    elif (txt in ['UrsaMajorII']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]

        label_y = plot_df['MHI_computed'].iat[i] - (plot_df['MHI_computed'].iat[i]*.20)

    elif (txt in ['AndromedaXXI']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]

        label_y = plot_df['MHI_computed'].iat[i] - (plot_df['MHI_computed'].iat[i]*.10)

    elif (txt in ['LMC','LeoT','LeoI','AndromedaXXIII','CetusII']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]

        label_y = plot_df['MHI_computed'].iat[i] + (plot_df['MHI_computed'].iat[i]*.15)

    elif (txt in ['AndromedaXIII']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]

        label_y = plot_df['MHI_computed'].iat[i] + (plot_df['MHI_computed'].iat[i]*.10)  

    elif (txt in ['GrusII','SegueII','TucanaIII','SagittariusII','DracoII','CarinaII','BootesII','Phoenix2']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]-15

        label_y = plot_df['MHI_computed'].iat[i]

    elif (txt in ['SagittariusdSph']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]-17

        label_y = plot_df['MHI_computed'].iat[i]  

    elif (txt in ['Reticulum2']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]-15

        label_y = plot_df['MHI_computed'].iat[i]+20

    elif (txt in ['ComaBerenices']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]+5

        label_y = plot_df['MHI_computed'].iat[i]

    elif (txt in ['TriangulumII']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]+3

        label_y = plot_df['MHI_computed'].iat[i]

    elif (txt in ['HydrusI']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]+2

        label_y = plot_df['MHI_computed'].iat[i]

    elif (txt in ['Eridanus3','AquariusII']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]-10

        label_y = plot_df['MHI_computed'].iat[i]

    elif (txt in ['Horologium1','AndromedaXX']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]-15

        label_y = plot_df['MHI_computed'].iat[i]-(plot_df['MHI_computed'].iat[i]*.15)

    elif (txt in ['NGC147']):

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]-32

        label_y = plot_df['MHI_computed'].iat[i]

    else:

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]

        label_y = plot_df['MHI_computed'].iat[i]

    

    plt.annotate(label,(label_x,label_y))

​

plt.xlim(0, 400)

plt.ylim(0, 1000000)

plt.axvline(250,color='C0',alpha=0.7)

plt.axvline(300,color='C1',alpha=0.7)

​

plt.legend(loc='lower right')

​

plt.title("HI Mass vs Distance from Milky Way or M31")

plt.ylabel("HI Mass or Mass Limit [$M_{\odot}$]")

plt.xlabel("Distance to Milky Way or M31, whichever is closer [kpc]")

plt.show()

/Users/janagrc/.pyenv/versions/jupyter3/lib/python3.6/site-packages/ipykernel_launcher.py:230: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
Invalid limit will be ignored.

Local Group Surface Distance

#MHI_computed vs Distance to LG surface

​

font = {'family' : 'normal',

        'weight' : 'normal',

        'size'   : 8}

​

SMALL_SIZE = 8

MEDIUM_SIZE = 10

BIGGER_SIZE = 12

​

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes

plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title

plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

​

plt.rc('font', **font)

​

sb.set_style("whitegrid")

​

plot_df = gals_merged[gals_merged['mw_dist'] < 2000]

plot_df.reset_index(drop=True, inplace=True)

label=[]

​

LG_model = 'ell_surf_dist'

​

plot_df.rename(columns = {'Closer_MW_M31':'Closer Galaxy'}, inplace = True)

plot_df.rename(columns = {'MHI_type':'Type'}, inplace = True)

plot_df.replace({'detected_mass': 'Detected Mass', 'upper_limit': 'Upper Limit'},inplace=True)

​

fg = sb.FacetGrid(data=plot_df, hue='MHI_source', height = 6,aspect=1.61)

fg.set(xscale="linear", yscale="log")

​

#fg.map(plt.scatter, 'min_dist_mw_or_m31', 'MHI_computed').add_legend()

fg = sb.scatterplot(x=plot_df[LG_model], y=plot_df['MHI_computed'],hue=plot_df['Closer Galaxy'],style=plot_df['Type'],markers={"Detected Mass": "s", "Upper Limit": "v"},s=90,edgecolor='none',alpha=0.7)

#print(gals_merged.count())

count = 0

for i, txt in enumerate(plot_df.GalaxyName):

    if((plot_df[LG_model][i] > 0) | (plot_df['Type'][i] == 'Detected Mass') | (plot_df['MHI_computed'][i] > 1000000)):

        if ('Andromeda' in txt):

            roman = txt.split('Andromeda')

            roman = ''.join(roman)

            label = "And " + roman

        elif ('LeoT' in txt):

            label = "Leo T"

        elif ('EridanusII' in txt):

            label = "Eridanus II"

        elif ('LeoA' in txt):

            label = "Leo A"

        elif ('LeoP' in txt):

            label = "Leo P"

        elif ('LeoI' in txt):

            label = "Leo I"

        elif ('AntliaB' in txt):

            label = "Antlia B"

        elif ('SagittariusdIrr' in txt):

            label = "Sag dIrr"

        elif ('SextansA' in txt):

            label = "Sextans A"

        elif ('SextansB' in txt):

            label = "Sextans B"

        elif ('PerseusI' in txt):

            label = "Perseus I"

        elif ('CetusIII' in txt):

            label = "Cetus III"

        elif ('PegasusdIrr' in txt):

            label = "Peg dIrr"

        else:

            label = txt

            

        if (txt in ['LMC','KKR25']):

            label_x = plot_df[LG_model].iat[i]

            label_y = plot_df['MHI_computed'].iat[i] - (plot_df['MHI_computed'].iat[i]*.2)

        elif (txt in []):

            label_x = plot_df[LG_model].iat[i]

            label_y = plot_df['MHI_computed'].iat[i] + (plot_df['MHI_computed'].iat[i]*.27)

        else:

            label_x = plot_df[LG_model].iat[i]

            label_y = plot_df['MHI_computed'].iat[i]

        plt.annotate(label,(label_x,label_y))

​

plt.xlim(-350, 2005)

plt.legend(loc='lower right')

#plt.axvline(250,color='steelblue')

#plt.axvline(300,color='darkorange')

plt.axvline(0,color='darkgray')

​

plt.title("HI Mass vs Distance from Local Group Surface")

plt.ylabel("HI Mass or Mass Limit [$M_{\odot}$]")

plt.xlabel("Distance from LG Surface [kpc]")

plt.show()

gals_merged[gals_merged['GalaxyName'] == 'Bootes(I)']

	GalaxyName 	RA_hr 	RA_min 	RA_sec 	Dec_deg 	Dec_arcmin 	Dec_arcsec 	EB-V 	m-M 	m-M_err_pos 	... 	MHI/M_V 	L_V 	MHI/L_V 	r_ell 	ell_surf_dist 	mw_dist 	m31_dist 	ell_surf_log10_abs 	min_dist_mw_or_m31 	Closer_MW_M31

0 rows × 142 columns

#MHI_computed vs Distance to LG surface

​

font = {'family' : 'normal',

        'weight' : 'normal',

        'size'   : 8}

​

SMALL_SIZE = 8

MEDIUM_SIZE = 10

BIGGER_SIZE = 12

​

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes

plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title

plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

​

plt.rc('font', **font)

​

sb.set_style("whitegrid")

​

plot_df = gals_merged[gals_merged['mw_dist'] < 2000]

plot_df.reset_index(drop=True, inplace=True)

label=[]

​

LG_model = 'ell_surf_dist'

​

plot_df.rename(columns = {'Closer_MW_M31':'Closer Galaxy'}, inplace = True)

plot_df.rename(columns = {'MHI_type':'Type'}, inplace = True)

plot_df.replace({'detected_mass': 'Detected Mass', 'upper_limit': 'Upper Limit'},inplace=True)

​

fg = sb.FacetGrid(data=plot_df, hue='MHI_source', height = 6,aspect=1.61)

fg.set(xscale="linear", yscale="log")

​

fg = sb.scatterplot(x=plot_df['ell_surf_dist'], y=plot_df['MHI_computed'],hue=plot_df['Closer Galaxy'],style=plot_df['Type'],markers={"Detected Mass": "s", "Upper Limit": "v"},s=90,edgecolor='none',alpha=0.7)

​

for i, txt in enumerate(plot_df['GalaxyName']):

    if((plot_df['ell_surf_dist'][i] < 50) & ((plot_df['MHI_computed'][i] < 1000000))):

        if ('Andromeda' in txt):

            roman = txt.split('Andromeda')

            roman = ''.join(roman)

            label = "A" + roman

        elif ('Sag' in txt):

            tag = re.findall(r"dSph",txt) + re.findall(r"II",txt) + re.findall(r"dIrr",txt)

            tag = ''.join(tag)

            label = "Sag" + tag

        elif ('Tuc' in txt):

            tag = re.findall(r"I",txt) + re.findall(r"V",txt) + re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Tuc" + tag

        elif ('Horo' in txt):

            tag = re.findall(r"I",txt) + re.findall(r"1",txt)

            tag = ''.join(tag)

            label = "Horo" + tag

        elif ('Retic' in txt):

            tag = re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Ret" + tag

        elif ('UrsaMajor' in txt):

            tag = re.findall(r"I",txt) + re.findall(r"1",txt)

            tag = ''.join(tag)

            label = "UMa" + tag

        elif ('Bootes' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)

            tag = ''.join(tag)

            label = "Boo" + tag

        elif ('Carina' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Car" + tag

        elif ('Segue' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Seg" + tag

        elif ('Hydr' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Hyd" + tag

        elif ('Cetus' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Cet" + tag

        elif ('Triangulum' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Tri" + tag

        elif ('ComaBerenices' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Com" + tag

        elif ('UrsaMinor' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "UMi" + tag

        elif ('Pisces' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Psc" + tag

        elif ('Pictor' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Pic" + tag

        elif ('Eridan' in txt):

            tag =  re.findall(r"3",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Eri" + tag

        elif ('Hercules' in txt):

            tag =  re.findall(r"3",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Her" + tag

        elif ('CanesVenatici' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "CVn" + tag

        elif ('Columba' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Col" + tag

        elif ('Pegasus' in txt):

            tag =  re.findall(r"3",txt)+re.findall(r"dIrr",txt)

            tag = ''.join(tag)

            label = "Peg" + tag

        elif ('Draco' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Dra" + tag

        elif ('Phoenix' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"1",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Phe" + tag

        elif ('Sextans' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"A",txt)+re.findall(r"B",txt)

            tag = ''.join(tag)

            label = "Sex" + tag

        elif ('Tucana' in txt):

            tag =  re.findall(r"I",txt) + re.findall(r"V",txt)+re.findall(r"2",txt)

            tag = ''.join(tag)

            label = "Tuc" + tag

        elif ('Virgo' in txt):

            tag =  re.findall(r"I",txt)

            tag = ''.join(tag)

            label = "Vir" + tag

        elif ('Aquarius' in txt):

            tag =  re.findall(r"I",txt)

            tag = ''.join(tag)

            label = "Aqr" + tag

        elif ('Sculptor' in txt):

            tag =  re.findall(r"I",txt)

            tag = ''.join(tag)

            label = "Scl" + tag

        elif ('Crater' in txt):

            tag =  re.findall(r"I",txt)

            tag = ''.join(tag)

            label = "Crt" + tag

        elif ('Fornax' in txt):

            tag =  re.findall(r"I",txt)

            tag = ''.join(tag)

            label = "For" + tag

        elif ('Grus' in txt):

            tag =  re.findall(r"I",txt)

            tag = ''.join(tag)

            label = "Gru" + tag

        elif ('Cassiopeia' in txt):

            tag =  re.findall(r"I",txt)

            tag = ''.join(tag)

            label = "Cas" + tag

        elif ('Lacerta' in txt):

            tag =  re.findall(r"I",txt)

            tag = ''.join(tag)

            label = "Lac" + tag

        elif ('Perseus' in txt):

            tag =  re.findall(r"I",txt)

            tag = ''.join(tag)

            label = "Per" + tag

        else:

            label = txt

            

            

        if(pd.notna(plot_df['ell_surf_dist'].iat[i]) & pd.notna(plot_df['MHI_computed'].iat[i])):  

            if (txt in ['AndromedaII','AndromedaXXX','TucanaV','SMC','Antlia','KKR25','CassiopeiaIII','DESJ0225+0304','Tucana','HorologiumII','BootesIII']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI_computed'].iat[i] - (plot_df['MHI_computed'].iat[i]*.15)

            elif (txt in ['UrsaMajorII','Draco']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI_computed'].iat[i] - (plot_df['MHI_computed'].iat[i]*.20)

            elif (txt in ['AndromedaXXI','UrsaMinor','AndromedaXIV']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI_computed'].iat[i] - (plot_df['MHI_computed'].iat[i]*.10)

            elif (txt in ['LMC','LeoT']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI_computed'].iat[i] + (plot_df['MHI_computed'].iat[i]*.15)

            elif (txt in ['AndromedaXIII','AndromedaXXIII']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI_computed'].iat[i] + (plot_df['MHI_computed'].iat[i]*.10)  

            elif (txt in ['GrusII','SegueII','TucanaIII','SagittariusII','DracoII','CarinaII','BootesII','Phoenix2']):

                label_x = plot_df['ell_surf_dist'].iat[i]-14

                label_y = plot_df['MHI_computed'].iat[i]

            elif (txt in ['SagittariusdSph']):

                label_x = plot_df['ell_surf_dist'].iat[i]-30

                label_y = plot_df['MHI_computed'].iat[i]  

            elif (txt in ['Reticulum2']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI_computed'].iat[i]+20

            elif (txt in []):

                label_x = plot_df['ell_surf_dist'].iat[i]+5

                label_y = plot_df['MHI_computed'].iat[i]

            elif (txt in ['TriangulumII']):

                label_x = plot_df['ell_surf_dist'].iat[i]+3

                label_y = plot_df['MHI_computed'].iat[i]

            elif (txt in ['HydrusI']):

                label_x = plot_df['ell_surf_dist'].iat[i]+7

                label_y = plot_df['MHI_computed'].iat[i]

            elif (txt in ['Eridanus3','AquariusII']):

                label_x = plot_df['ell_surf_dist'].iat[i]-10

                label_y = plot_df['MHI_computed'].iat[i]

            elif (txt in ['Horologium1']):

                label_x = plot_df['ell_surf_dist'].iat[i]-15

                label_y = plot_df['MHI_computed'].iat[i]-(plot_df['MHI_computed'].iat[i]*.15)

            elif (txt in ['Bootes(I)']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI_computed'].iat[i]-(plot_df['MHI_computed'].iat[i]*.20)

            else:

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI_computed'].iat[i]

​

            plt.annotate(label,(label_x,label_y))

​

plt.xlim(-300, 100)

plt.ylim(10, 1000000)

​

plt.legend(loc='lower right')

#plt.axvline(250,color='steelblue')

#plt.axvline(300,color='darkorange')

plt.axvline(0,color='darkgray')

​

plt.title("HI Mass vs Distance from Local Group Surface")

plt.ylabel("HI Mass or Mass Limit [$M_{\odot}$]")

plt.xlabel("Distance from LG Surface [kpc]")

plt.show()

Morphology labels, Full D, MHI_computed vs min dist to m31 or mw, whichever is closer

gals_merged['Morphology'].unique()

array(['dSph', nan, 'dSph?', 'Irr', 'dIrr', 'cE', 'dE/dSph', 'dIrr/dSph',
       '(d)Irr?'], dtype=object)

#Full range of D, MHI_computed vs min dist to m31 or mw, whichever is closer

​

font = {'family' : 'normal',

        'weight' : 'normal',

        'size'   : 10}

​

SMALL_SIZE = 8

MEDIUM_SIZE = 10

BIGGER_SIZE = 12

​

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes

plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title

plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

​

plt.rc('font', **font)

​

sb.set_style("whitegrid")

​

​

plot_df = gals_merged[gals_merged['mw_dist'] < 2000]

plot_df.reset_index(drop=True, inplace=True)

label=[]

​

​

plot_df.rename(columns = {'Closer_MW_M31':'Closer Galaxy'}, inplace = True)

plot_df.rename(columns = {'MHI_type':'Type'}, inplace = True)

​

plot_df.replace({'detected_mass': 'Detected Mass', 'upper_limit': 'Upper Limit'},inplace=True)

​

fg = sb.FacetGrid(data=plot_df, hue='MHI_source', height = 6,aspect=1.61)

fg.set(xscale="linear", yscale="log")

​

#fg.map(plt.scatter, 'min_dist_mw_or_m31', 'MHI_computed').add_legend()

fg = sb.scatterplot(x=plot_df['min_dist_mw_or_m31'], y=plot_df['MHI_computed'],hue=plot_df['Closer Galaxy'],s=90)

#print(gals_merged.count())

count = 0

for i, txt in enumerate(plot_df.Morphology):

    if((((plot_df['Closer Galaxy'][i] == 'M31') & (plot_df['min_dist_mw_or_m31'][i] > 300)) | ((plot_df['Closer Galaxy'][i] == 'MW') & (plot_df['min_dist_mw_or_m31'][i] > 250)) | (plot_df['Type'][i] == 'Detected Mass') | (plot_df['MHI_computed'][i] > 1000000))):

        label = txt

        label_x = plot_df['min_dist_mw_or_m31'].iat[i]

        label_y = plot_df['MHI_computed'].iat[i]

        plt.annotate(label,(label_x,label_y))

​

plt.xlim(0, 2100)

plt.axvline(250,color='steelblue')

plt.axvline(300,color='darkorange')

​

plt.legend(loc='lower right')

​

plt.title("HI Mass vs Distance from Milky Way or M31")

plt.ylabel("HI Mass or Mass Limit [$M_{\odot}$]")

plt.xlabel("Distance to Milky Way or M31, whichever is closer [kpc]")

plt.show()

Morphology labels, Zoomed D, MHI_computed vs min dist to m31 or mw, whichever is closer

​

font = {'family' : 'normal',

        'weight' : 'normal',

        'size'   : 10}

​

SMALL_SIZE = 8

MEDIUM_SIZE = 10

BIGGER_SIZE = 12

​

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes

plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title

plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

​

plt.rc('font', **font)

​

sb.set_style("whitegrid")

​

​

plot_df = gals_merged[gals_merged['mw_dist'] < 2000]

plot_df.reset_index(drop=True, inplace=True)

label=[]

​

​

plot_df.rename(columns = {'Closer_MW_M31':'Closer Galaxy'}, inplace = True)

plot_df.rename(columns = {'MHI_type':'Type'}, inplace = True)

​

plot_df.replace({'detected_mass': 'Detected Mass', 'upper_limit': 'Upper Limit'},inplace=True)

​

fg = sb.FacetGrid(data=plot_df, hue='MHI_source', height = 6,aspect=1.61)

fg.set(xscale="linear", yscale="log")

​

#fg.map(plt.scatter, 'min_dist_mw_or_m31', 'MHI_computed').add_legend()

fg = sb.scatterplot(x=plot_df['min_dist_mw_or_m31'], y=plot_df['MHI_computed'],hue=plot_df['Closer Galaxy'],style=plot_df['Type'],markers={"Detected Mass": "s", "Upper Limit": "v"},s=90)

#print(gals_merged.count())

count = 0

for i, txt in enumerate(plot_df.Morphology):

    if((((plot_df['Closer Galaxy'][i] == 'M31') & (plot_df['min_dist_mw_or_m31'][i] < 400)) | ((plot_df['Closer Galaxy'][i] == 'MW') & (plot_df['min_dist_mw_or_m31'][i] < 400)))):

        if((plot_df['Morphology'].iat[i] != 'nan') & (~pd.isnull(plot_df['min_dist_mw_or_m31'].iat[i])) & (~pd.isnull(plot_df['MHI_computed'].iat[i]))):

            #print(i,plot_df['GalaxyName'].iat[i],plot_df['min_dist_mw_or_m31'][i],plot_df['MHI_computed'].iat[i],txt)

            label = txt

            label_x = plot_df['min_dist_mw_or_m31'].iat[i]

            label_y = plot_df['MHI_computed'].iat[i]

            plt.annotate(label,(label_x,label_y))

​

plt.xlim(0, 400)

plt.axvline(250,color='steelblue')

plt.axvline(300,color='darkorange')

​

plt.legend(loc='lower right')

​

plt.title("HI Mass vs Distance from Milky Way or M31")

plt.ylabel("HI Mass or Mass Limit [$M_{\odot}$]")

plt.xlabel("Distance to Milky Way or M31, whichever is closer [kpc]")

plt.show()

Local Group Surface distance vs M_HI normalized by L_V

#Full range of D, LG surf dist vs MHI_computed normalized by L_v

​

#Zoomed in D, MHI_computed vs min dist to m31 or mw, whichever is closer

​

font = {'family' : 'normal',

        'weight' : 'normal',

        'size'   : 10}

​

SMALL_SIZE = 12

MEDIUM_SIZE = 14

BIGGER_SIZE = 16

​

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes

plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title

plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

​

plt.rc('font', **font)

​

sb.set_style("whitegrid")

plot_df = gals_merged[gals_merged['mw_dist'] < 2000]

plot_df.reset_index(drop=True, inplace=True)

label=[]

​

plot_df.rename(columns = {'Closer_MW_M31':'Closer Galaxy'}, inplace = True)

plot_df.rename(columns = {'MHI_type':'Type'}, inplace = True)

​

plot_df.replace({'detected_mass': 'Detected Mass', 'upper_limit': 'Upper Limit'},inplace=True)

​

fg = sb.FacetGrid(data=plot_df, hue='MHI_source', height = 6,aspect=1.61)

fg.set(xscale="linear", yscale="log")

​

#fg.map(plt.scatter, 'min_dist_mw_or_m31', 'MHI_computed').add_legend()

fg = sb.scatterplot(x=plot_df['ell_surf_dist'], y=plot_df['MHI/L_V'],hue=plot_df['Closer Galaxy'],style=plot_df['Type'],markers={"Detected Mass": "s", "Upper Limit": "v"},s=90,edgecolor='none',alpha=0.7)

#print(gals_merged.count())

count = 0

plot_df.reset_index(drop=True, inplace=True)

​

for i, txt in enumerate(plot_df['GalaxyName']):

    if((plot_df['ell_surf_dist'][i] > 0) | ((plot_df['Type'][i] == "Detected Mass"))):

        if ('Andromeda' in txt):

            roman = txt.split('Andromeda')

            roman = ''.join(roman)

            label = "A" + roman

        elif ('LeoT' in txt):

            label = "Leo T"

        elif ('EridanusII' in txt):

            label = "Eridanus II"

        elif ('LeoA' in txt):

            label = "Leo A"

        elif ('LeoP' in txt):

            label = "Leo P"

        elif ('LeoI' in txt):

            label = "Leo I"

        elif ('AntliaB' in txt):

            label = "Antlia B"

        elif ('SagittariusdIrr' in txt):

            label = "Sag dIrr"

        elif ('SextansA' in txt):

            label = "Sextans A"

        elif ('SextansB' in txt):

            label = "Sextans B"

        elif ('PerseusI' in txt):

            label = "Perseus I"

        elif ('CetusIII' in txt):

            label = "Cetus III"

        elif ('PegasusdIrr' in txt):

            label = "Peg dIrr"

        else:

            label = txt

         

            

        if(pd.notna(plot_df['ell_surf_dist'].iat[i]) & pd.notna(plot_df['MHI/L_V'].iat[i])):  

            if (txt in ['ESO410-G005','NGC205','AntliaB','IC1613','WLM']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI/L_V'].iat[i] - (plot_df['MHI/L_V'].iat[i]*.2)

            elif (txt in ['PegasusdIrr']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI/L_V'].iat[i] - (plot_df['MHI/L_V'].iat[i]*.1)

            elif (txt in ['EridanusII','SagittariusdIrr']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI/L_V'].iat[i] - (plot_df['MHI/L_V'].iat[i]*.3)

            elif (txt in ['AndromedaXVIII']):

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI/L_V'].iat[i] + (plot_df['MHI/L_V'].iat[i]*.2)

            elif (txt in ['IC10','LGS3']):

                label_x = plot_df['ell_surf_dist'].iat[i]-70

                label_y = plot_df['MHI/L_V'].iat[i]

            else:

                label_x = plot_df['ell_surf_dist'].iat[i]

                label_y = plot_df['MHI/L_V'].iat[i]

​

            plt.annotate(label,(label_x,label_y))

​

plt.xlim(np.min(plot_df['ell_surf_dist']-20), 2000)

#plt.ylim(10, 1000000)

​

plt.legend(loc='lower right')

#plt.axvline(250,color='steelblue')

#plt.axvline(300,color='darkorange')

plt.axvline(0,color='darkgray')

​

plt.title("Distance from Local Group Surface vs HI Mass normalized by L$_{V}$")

plt.ylabel("$\\frac{M_{HI}}{L_{V}}$ [$\\frac{M_{\odot}}{L_{\odot}}$]")

plt.xlabel("Distance from LG Surface [kpc]")

plt.legend(loc='lower right')

plt.show()
